# %% [markdown]
# # A few refresher exercises to get back in the saddle
#
# Lino Galiana
# 2025-12-26
#
# Le contenu de cette page est disponible sur [le site web du cours](pythonds.linogaliana.fr/content/getting-started/04_revisions.html)
#
# # 1. Synthesis exercises
#
# To make sure you are fluent on data structures and operations in `Python` for different problems, here is a series of exercises.
#
# They require you to think hard about the appropriate data structure to answer - that’s normal!
#
# For once, the exercises are done directly on this page rather than via *notebooks*[1]. The correction will soon be available on the [dedicated page](../../content/appendix/corrections.qmd).
#
# ## 1.1 Exercice 1
#
# > **Tip**
# >
# > <div class="callout callout-style-default callout-tip callout-titled">
# > <div class="callout-header d-flex align-content-center">
# > <div class="callout-icon-container">
# > <i class="callout-icon"></i>
# > </div>
# > <div class="callout-title-container flex-fill">
# > Exercice 1
# > </div>
# > </div>
# > <div class="callout-body-container callout-body">
# >
# > You have at your disposal a list of quotations from the magnificent French literary heritage:
# >
# > <details>
# >
# > <summary>
# >
# > See the list of quotations that will be useful
# >
# > </summary>
# >
# > | Citation | Auteur |
# > |----------------------------------|--------------------------------------|
# > | “Rien ne sert de courir ; il faut partir à point.” | La Fontaine |
# > | “Selon que vous serez puissant ou misérable, les jugements de cour vous rendront blanc ou noir.” | La Fontaine |
# > | “Heureux qui comme Ulysse a fait bon voyage” | Du Bellay |
# > | “L’homme est né libre, et partout il est dans les fers.” | Rousseau |
# > | “Parce que c’était lui, parce que c’était moi.” | Montaigne |
# > | “La première fois qu’Aurélien vit Bérénice, il la trouva franchement laide” | Aragon |
# > | “Aujourd’hui maman est morte. Ou peut-être hier, je ne sais pas.” | Camus |
# >
# > </details>
# >
# > Create a `citations` object that uses a suitable data structure in `Python` to:
# >
# > 1.  Easily retrieve all quotations associated with an author. Create a `citation_aragon` object that tests the validity of your approach with the Aragon example.
# > 2.  For each quotation, count the number of words and the number of unique words. Create a `stats_phrases` object that lists these properties. Test on La Fontaine quotations.
# >
# > </div>
# > </div>
#
# Here are the quotes, in bulk, to get you started.
#
# In this cell, create the appropriate data structure for this exercise.
#
# <script type="pyodide-1-contents">
# ...
# </script>
#
# > **Note**
# >
# > <div class="callout callout-style-default callout-note callout-titled">
# > <div class="callout-header d-flex align-content-center">
# > <div class="callout-icon-container">
# > <i class="callout-icon"></i>
# > </div>
# > <div class="callout-title-container flex-fill">
# > Hint 1
# > </div>
# > </div>
# > <div class="callout-body-container callout-body">
# >
# > What data structure would enable this type of code?
# >
# > ``` python
# > citations.get("La Fontaine")
# > ```
# >
# > </div>
# > </div>
#
# > **Note**
# >
# > <div class="callout callout-style-default callout-note callout-titled">
# > <div class="callout-header d-flex align-content-center">
# > <div class="callout-icon-container">
# > <i class="callout-icon"></i>
# > </div>
# > <div class="callout-title-container flex-fill">
# > Hint 2
# > </div>
# > </div>
# > <div class="callout-body-container callout-body">
# >
# > What data structure could make an object look like
# >
# > ``` js
# > citations
# > ```
# >
# > </div>
# > </div>
#
# [1] It is possible to run `Python` on the browser thanks to its implementation in WASM via [Pyodide](https://pyodide.org/en/stable/). This is not a recommended method when you need to perform big calculations, as in the next chapters. But since we are working on small examples here, this is quite practical to benefit from the interactivity enabled by the browser, notably the helpers in case ou are blocked.

# %%
citations = {
  "La Fontaine": [
    "Rien ne sert de courir ; il faut partir à point.",
    "Selon que vous serez puissant ou misérable, les jugements de cour vous rendront blanc ou noir."
  ],
  "Du Bellay": [
    "Heureux qui comme Ulysse a fait bon voyage"
  ],
  "Rousseau": [
    "L'homme est né libre, et partout il est dans les fers."
  ],
  "Aragon": [
    "La première fois qu'Aurélien vit Bérénice, il la trouva franchement laide"
  ],
  "Camus": [
    "Aujourd'hui maman est morte. Ou peut-être hier, je ne sais pas."
  ],
}

# %%
ojs_define(citations = citations)
# Out:
# <script type="ojs-define">{"contents": [{"name": "citations", "value": {"La Fontaine": ["Rien ne sert de courir ; il faut partir \u00e0 point.", "Selon que vous serez puissant ou mis\u00e9rable, les jugements de cour vous rendront blanc ou noir."], "Du Bellay": ["Heureux qui comme Ulysse a fait bon voyage"], "Rousseau": ["L'homme est n\u00e9 libre, et partout il est dans les fers."], "Aragon": ["La premi\u00e8re fois qu'Aur\u00e9lien vit B\u00e9r\u00e9nice, il la trouva franchement laide"], "Camus": ["Aujourd'hui maman est morte. Ou peut-\u00eatre hier, je ne sais pas."]}}]}</script>

# %% [markdown]
# For question 1, you can use this cell.
#
# <script type="pyodide-2-contents">
# eyJhdHRyIjp7ImVkaXQiOnRydWUsImV2YWwiOnRydWUsImV4ZXJjaXNlIjoiZXhfMV9xMSJ9LCJjb2RlIjoiIyBUZXN0ZXIgaWNpIHZvdHJlIHLDqXBvbnNlIMOgIGxhIHF1ZXN0aW9uIDEifQ==
# </script>

# %%
def citations_auteur(citations: dict, auteur: str = "Camus"):
  return citations.get(auteur)

citation_aragon = citations_auteur(citations, "Aragon")

# %% [markdown]
# For question 2, you can use this cell.
#
# <script type="pyodide-3-contents">
# eyJhdHRyIjp7ImVkaXQiOnRydWUsImV2YWwiOnRydWUsImV4ZXJjaXNlIjoiZXhfMV9xMiJ9LCJjb2RlIjoic3RhdHNfcGhyYXNlcyA9IF9fXyJ9
# </script>

# %%
stats_phrases = {}

for auteur, liste_citations in citations.items():
  stats_phrases[auteur] = {
    "longueur": [len(c.split()) for c in liste_citations],
    "unique": [len(set(c.split())) for c in liste_citations],
  }

# %% [markdown]
# > **Note**
# >
# > <div class="callout callout-style-default callout-note callout-titled">
# > <div class="callout-header d-flex align-content-center">
# > <div class="callout-icon-container">
# > <i class="callout-icon"></i>
# > </div>
# > <div class="callout-title-container flex-fill">
# > Hint 1
# > </div>
# > </div>
# > <div class="callout-body-container callout-body">
# >
# > How do you iterate over the keys and values of your `stats_phrases` dict?
# >
# > </div>
# > </div>
#
# > **Note**
# >
# > <div class="callout callout-style-default callout-note callout-titled">
# > <div class="callout-header d-flex align-content-center">
# > <div class="callout-icon-container">
# > <i class="callout-icon"></i>
# > </div>
# > <div class="callout-title-container flex-fill">
# > Hint 2
# > </div>
# > </div>
# > <div class="callout-body-container callout-body">
# >
# > Adopt this general structure :
# >
# > ``` python
# > for auteur, liste_citations in citations.items():
# >     # do something
# > ```
# >
# > How to have the length of a sentence (sequence of words) and single words in it?
# >
# > </div>
# > </div>
#
# > **Note**
# >
# > <div class="callout callout-style-default callout-note callout-titled">
# > <div class="callout-header d-flex align-content-center">
# > <div class="callout-icon-container">
# > <i class="callout-icon"></i>
# > </div>
# > <div class="callout-title-container flex-fill">
# > Hint 3
# > </div>
# > </div>
# > <div class="callout-body-container callout-body">
# >
# > How can I get the length of a sentence (sequence of words) and the single words in it?
# >
# > 1.  A sentence (string) can be broken down into words (list) using the `split()` method.
# > 2.  A `set` can be used to deduplicate a list
# >
# > </div>
# > </div>
#
# > **Note**
# >
# > <div class="callout callout-style-default callout-note callout-titled">
# > <div class="callout-header d-flex align-content-center">
# > <div class="callout-icon-container">
# > <i class="callout-icon"></i>
# > </div>
# > <div class="callout-title-container flex-fill">
# > Hint 4
# > </div>
# > </div>
# > <div class="callout-body-container callout-body">
# >
# > You should get this type of result:
# >
# > ``` js
# > stats_phrases
# > ```
# >
# > </div>
# > </div>

# %%
ojs_define(stats_phrases = stats_phrases)
# Out:
# <script type="ojs-define">{"contents": [{"name": "stats_phrases", "value": {"La Fontaine": {"longueur": [11, 16], "unique": [11, 14]}, "Du Bellay": {"longueur": [8], "unique": [8]}, "Rousseau": {"longueur": [11], "unique": [10]}, "Aragon": {"longueur": [11], "unique": [11]}, "Camus": {"longueur": [11], "unique": [11]}}}]}</script>

# %% [markdown]
# > **Warning**
# >
# > <div class="callout callout-style-default callout-warning callout-titled">
# > <div class="callout-header d-flex align-content-center">
# > <div class="callout-icon-container">
# > <i class="callout-icon"></i>
# > </div>
# > <div class="callout-title-container flex-fill">
# > Warning
# > </div>
# > </div>
# > <div class="callout-body-container callout-body">
# >
# > Ideally, you should pay attention to punctuation.
# >
# > But we have not yet learned how to make refined substitutions in strings - that will come in another chapter.
# >
# > </div>
# > </div>
#
# ## 1.2 Exercise 2
#
# Advent of Code challenges are excellent practical problems for learning algorithms. With one problem per day of increasing difficulty between 1 December and Christmas Day, you will quickly become comfortable with the many data structures offered by Python.
#
# The next exercise proposes solving the first part of day 1 (year 2022) using only basic Python.
#
# > **Warning**
# >
# > <div class="callout callout-style-default callout-warning callout-titled">
# > <div class="callout-header d-flex align-content-center">
# > <div class="callout-icon-container">
# > <i class="callout-icon"></i>
# > </div>
# > <div class="callout-title-container flex-fill">
# > Warning
# > </div>
# > </div>
# > <div class="callout-body-container callout-body">
# >
# > It would be appropriate to use Numpy for the next problem. But the purpose of the next chapter is to show how this package simplifies basic numerical operations.
# >
# > </div>
# > </div>
#
# Here are the objects we will need for this exercise:

# %%
import requests

url = "https://minio.lab.sspcloud.fr/lgaliana/python-ENSAE/inputs/aoc2022_day1.txt"
elves = requests.get(url).text.split("\n\n")


example = """
1000
2000
3000

4000

5000
6000

7000
8000
9000

10000
"""

elves_example = example.split("\n\n")

# %% [markdown]
# <script type="pyodide-4-contents">
# ...
# </script>
#
# You can write your code for question 2 in this cell:
#
# <script type="pyodide-5-contents">
# eyJhdHRyIjp7ImVkaXQiOnRydWUsImV2YWwiOnRydWUsImV4ZXJjaXNlIjoiZXhfMl9xMiJ9LCJjb2RlIjoiIyBUZXN0IGhlcmUgeW91ciBzb2x1dGlvbiB0byBxdWVzdGlvbiAyIn0=
# </script>
#
# > **Note**
# >
# > <div class="callout callout-style-default callout-note callout-titled">
# > <div class="callout-header d-flex align-content-center">
# > <div class="callout-icon-container">
# > <i class="callout-icon"></i>
# > </div>
# > <div class="callout-title-container flex-fill">
# > Hint 1
# > </div>
# > </div>
# > <div class="callout-body-container callout-body">
# >
# > We will need to iterate over each value of `elves_example`: how can we transform the character string into a more manageable object?
# >
# > </div>
# > </div>
#
# > **Note**
# >
# > <div class="callout callout-style-default callout-note callout-titled">
# > <div class="callout-header d-flex align-content-center">
# > <div class="callout-icon-container">
# > <i class="callout-icon"></i>
# > </div>
# > <div class="callout-title-container flex-fill">
# > Hint 2
# > </div>
# > </div>
# > <div class="callout-body-container callout-body">
# >
# > Be careful with the type of object you will obtain. Don’t forget to convert it to a numeric format if you want to perform arithmetic operations.
# >
# > </div>
# > </div>

# %%
calories_example

# %%
# Question 2
calories_example = []
for idx, elf in enumerate(elves_example):
  calories_example += [
    sum(map(int, elf.strip().split("\n")))
  ]

# %% [markdown]
# You can write your code for question 3 in this cell:
#
# <script type="pyodide-6-contents">
# eyJhdHRyIjp7ImVkaXQiOnRydWUsImV2YWwiOnRydWUsImV4ZXJjaXNlIjoiZXhfMl9xMyJ9LCJjb2RlIjoiIyBRdWVzdGlvbiAzIn0=
# </script>

# %%
# Question 3
idx_max = calories_example.index(max(calories_example))
idx_min = calories_example.index(min(calories_example))

# %%
# Question 4
def process_calories(elf) -> list[list[int]]:
    elves_split = [
      list(
        map(int, elf.strip().split("\n"))
      ) for elf in elves]
    return elves_split

data = process_calories(elves)
calories_total = [sum(d) for d in data]

# %% [markdown]
# Finally, after generalizing, you should find the following values:

# %%
idx_elf = calories_total.index(max(calories_total))
max_elf = max(calories_total)
print(
  f"Elf number {idx_elf} carries the most calories ({max_elf} calories)."
)
# Out:
# Elf number 217 carries the most calories (72602 calories).

# %% [markdown]
# <script type="pyodide-7-contents">
# eyJhdHRyIjp7ImVkaXQiOnRydWUsImV2YWwiOnRydWUsImV4ZXJjaXNlIjoiZXhfMl9xNCJ9LCJjb2RlIjoiIyBRdWVzdGlvbiA0In0=
# </script>
#
# ## 1.3 Exercise 3: strings
#
# This is the final pattern you should end up in question 1 and 2
#
#     On 17 March 2022, Nadia (34) reported an income of $33,333.33.
#
# ## 1.4 Exercise 3
#
# 1.  Using the `format` method, try to obtain the expected result.
# 2.  Do the same with *f-strings*.
# 3.  Modify the message to create a monthly income rounded to 1 digit. Use a space as the thousands separator rather than the default separator (the comma).
# 4.  Here is a fictitious path `C:\Users\Nadia\Documents\cours\chapitre_03\notes.txt` to a file. Make a correct print of it.

# %%
import datetime

date = datetime.datetime(2022, 3, 17)
prenom = "Nadia"
age = 34
revenu = 100000/3

# %% [markdown]
# In the first part of this exercise, you should have these results.

# %%
# Question 1
msg_format = "On {date:%d %B %Y}, {prenom} ({age}) reported an income of ${revenu:,.2f}.".format(
    date=date, prenom=prenom, age=age, revenu=revenu
)

print("Question 1:")
print(msg_format)

# Question 2
msg_fstring = f"On {date:%d %B %Y}, {prenom} ({age}) reported an income of ${revenu:,.2f}."

print("Question 2:")
print(msg_fstring)

# Question 3
msg_fstring = f"On {date:%d %B %Y}, {prenom} ({age}) reported an income of ${revenu/12:,.1f}.".replace(',', ' ')

print("Question 3:")
print(msg_fstring)
# Out:
# Question 1:
# On 17 March 2022, Nadia (34) reported an income of $33,333.33.
# Question 2:
# On 17 March 2022, Nadia (34) reported an income of $33,333.33.
# Question 3:
# On 17 March 2022  Nadia (34) reported an income of $2 777.8.

# %% [markdown]
# In the second part of the exercise, if you use the wrong type of *string*, you should get an error:

# %%
# Question 4
chemin_bad = "C:\Users\Nadia\Documents\cours\chapitre_03\notes.txt"

print(chemin_bad)

# %% [markdown]
# Slashes often cause problems. With raw strings, you should not encounter this problem:

# %%
# Question 4
chemin_ok = r"C:\Users\Nadia\Documents\cours\chapitre_03\notes.txt"
print(f"File can be found here: {chemin_ok}")

# This alternative is ok
chemin_ok2 = "C:\\Users\\Nadia\\Documents\\cours\\chapitre_03\\notes.txt"
# Out:
# File can be found here: C:\Users\Nadia\Documents\cours\chapitre_03\notes.txt

# %% [raw]
# <script type="pyodide-data">
# eyJvcHRpb25zIjp7ImVudiI6eyJQTE9UTFlfUkVOREVSRVIiOiJwbG90bHlfbWltZXR5cGUifSwiaW5kZXhVUkwiOiJodHRwczovL2Nkbi5qc2RlbGl2ci5uZXQvcHlvZGlkZS92MC4yOC4xL2Z1bGwvIn0sInBhY2thZ2VzIjp7InBrZ3MiOlsicHlvZGlkZV9odHRwIiwibWljcm9waXAiLCJpcHl0aG9uIl19fQ==
# </script>

# %% [raw]
# <script type="ojs-module-contents">
# ...
# </script>

# %% [raw]
# <script type="vfs-file">
# W10=
# </script>
